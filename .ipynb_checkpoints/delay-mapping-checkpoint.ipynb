# %%
import folium
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
from helpers import *

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return.
train_data = pd.read_csv("data/trip.csv", header=None, na_values='\\N')
train_data.columns = ["time", "time_formated", "id", "route_id", "vehicle_id", "vehicle_label", "delay", "lat", "lon", "general_weather", "temp", "temp_min", "temp_max", "visibility", "wind_speed"]
train_data["time_formated"] = pd.to_datetime(train_data["time_formated"])

# %%
all_data_map = folium.Map(location=[41.8781,-87.6298], zoom_start=9, tiles='Stamen Toner')
for name, row in train_data.iterrows():
    marker = folium.CircleMarker([row['lat'], row['lon']], radius=1, popup=str(row['delay']))
    marker.add_to(m2)
all_data_map.save('Maps/all_data_map.html')

# %%
color_coded_map = folium.Map(location=[41.8781,-87.6298], zoom_start=9, tiles='Stamen Toner')
train_delay['color'] = train_delay.apply(colorRange, axis=1)

for name, row in train_data.iterrows():
    marker = folium.CircleMarker([train_data['lat'], train_data['lon']], 
                                 opacity=0.5, radius=0.5, 
                                 color='#'+str(color)[2:], 
                                 fill_color='#'+str(color)[2:], 
                                 popup=train_delay['']
marker.add_to(color_coded_map)

# %%
loc_groups = train_data.groupby(['lat','lon'])
delay = loc_groups['delay']
delay_mean = delay.mean()
delay_mean['color'] = delay_mean.apply(delaycolors)

# %%
train_data.delay.value_counts()

# %%
sns.distplot(train_data['delay'])

# %%
sns.distplot(train_data['visibility'])
# Out:
# /Users/Joseph/Applications/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/Joseph/Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/Joseph/Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /Users/Joseph/Applications/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/Joseph/Applications/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.jointplot(x="delay", y="temp", data=train_data, size=8)

# %%
sns.regplot(x="delay", y="temp", data=train_data)

# %%
mod = smf.ols(formula='delay ~ temp', data=train_data)
res = mod.fit()
print(res.summary())

# %%
train_data.general_weather.value_counts()

# %%
train_data['normalized_delay'] = train_data['delay'] / (train_data['delay'].std() * 1)
# Out:
#             time              time_formated                id route_id  \
# 0   1.554010e+09 2019-03-31 01:19:36.171123   UP-N_UN835_V6_B     UP-N
# 1   1.554010e+09 2019-03-31 01:19:36.171123  BNSF_BN1328_V6_B     BNSF
# 2   1.554010e+09 2019-03-31 01:20:07.779114   UP-N_UN835_V6_B     UP-N
# 3   1.554010e+09 2019-03-31 01:20:07.779114  BNSF_BN1328_V6_B     BNSF
# 4   1.554010e+09 2019-03-31 01:20:39.113679   UP-N_UN835_V6_B     UP-N
# 5   1.554010e+09 2019-03-31 01:20:39.113679  BNSF_BN1328_V6_B     BNSF
# 6   1.554010e+09 2019-03-31 01:21:10.445159   UP-N_UN835_V6_B     UP-N
# 7   1.554010e+09 2019-03-31 01:21:10.445159  BNSF_BN1328_V6_B     BNSF
# 8   1.554010e+09 2019-03-31 01:21:41.826173   UP-N_UN835_V6_B     UP-N
# 9   1.554010e+09 2019-03-31 01:21:41.826173  BNSF_BN1328_V6_B     BNSF
# 10  1.554010e+09 2019-03-31 01:22:13.142666   UP-N_UN835_V6_B     UP-N
# 11  1.554010e+09 2019-03-31 01:22:13.142666  BNSF_BN1328_V6_B     BNSF
# 72        1297           8301     60  41.759590 -87.560623
# 73        1297           8301      0  41.758354 -87.559410
# 74        1297           8301     60  41.755688 -87.556503
# 75        1297           8301      0  41.753273 -87.553925
# 76        1297           8301      0  41.752422 -87.552986
# 77        1297           8301      0  41.752148 -87.552673
# 78        1297           8301     60  41.749565 -87.551872
# 79        1297           8301      0  41.745777 -87.551659
# 80        1297           8301      0  41.744522 -87.551582
# 81        1297           8301      0  41.742668 -87.551262
# 82        1297           8301      0  41.740555 -87.549263
# 83        1297           8301      0  41.738239 -87.548309
# 84        1297           8301      0  41.736271 -87.548058
# 85        1297           8301      0  41.732685 -87.547981
# 86        1297           8301      0  41.730541 -87.547905
# 87        1297           8301      0  41.728188 -87.547745
# 88        8535           2600      0  42.397629 -88.182083
# 89        8535           2600      0  42.397625 -88.182083
# 90        8535           2600      0  42.397640 -88.182083
# 91        8535           2600      0  42.397640 -88.182098
# 92        1279            830    120  41.783573 -87.589760
# 93        8504            327      0  41.727909 -87.667259
# 94        1363            831     60  41.776127 -87.591492
# 95        8593           1322    120  41.778103 -88.207146
# 96        8574            230      0  41.515347 -87.959641
# 97        8548           2722     60  41.989529 -88.109062
# 98        8535           2620      0  42.370098 -88.133003
# 99        8452            516     60  41.886688 -88.411682
#
#                                       general_weather    temp  temp_min  \
# 0   [{'id': 802, 'main': 'Clouds', 'description': ...  271.76    270.15
# 1   [{'id': 803, 'main': 'Clouds', 'description': ...  272.22    271.48
# 2   [{'id': 802, 'main': 'Clouds', 'description': ...  271.76    270.15
# 3   [{'id': 803, 'main': 'Clouds', 'description': ...  272.23    271.48
# 4   [{'id': 803, 'main': 'Clouds', 'description': ...  271.75    270.15
# 5   [{'id': 803, 'main': 'Clouds', 'description': ...  272.23    271.48
# 6   [{'id': 803, 'main': 'Clouds', 'description': ...  271.75    270.15
# 7   [{'id': 803, 'main': 'Clouds', 'description': ...  272.23    271.48
# 8   [{'id': 803, 'main': 'Clouds', 'description': ...  271.75    270.15
# 9   [{'id': 803, 'main': 'Clouds', 'description': ...  272.22    271.48
# 10  [{'id': 803, 'main': 'Clouds', 'description': ...  271.75    270.15
# 11  [{'id': 803, 'main': 'Clouds', 'description': ...  272.22    271.48
# 12  [{'id': 803, 'main': 'Clouds', 'description': ...  272.24    271.48
# 13  [{'id': 803, 'main': 'Clouds', 'description': ...  272.23    271.48
# 14  [{'id': 803, 'main': 'Clouds', 'description': ...  272.17    270.93
# 15  [{'id': 803, 'main': 'Clouds', 'description': ...  272.16    270.93
# 16  [{'id': 803, 'main': 'Clouds', 'description': ...  272.16    270.93
# 17  [{'id': 803, 'main': 'Clouds', 'description': ...  272.15    270.93
# 18  [{'id': 803, 'main': 'Clouds', 'description': ...  272.16    270.93
# 19  [{'id': 803, 'main': 'Clouds', 'description': ...  272.15    270.93
# 20  [{'id': 803, 'main': 'Clouds', 'description': ...  272.15    270.93
# 21  [{'id': 804, 'main': 'Clouds', 'description': ...  272.15    270.93
# 22  [{'id': 804, 'main': 'Clouds', 'description': ...  272.15    270.93
# 23  [{'id': 803, 'main': 'Clouds', 'description': ...  272.15    270.93
# 24  [{'id': 804, 'main': 'Clouds', 'description': ...  272.15    270.93
# 25  [{'id': 804, 'main': 'Clouds', 'description': ...  272.15    270.93
# 26  [{'id': 800, 'main': 'Clear', 'description': '...  269.09    268.15
# 27  [{'id': 800, 'main': 'Clear', 'description': '...  269.01    267.59
# 28  [{'id': 800, 'main': 'Clear', 'description': '...  269.01    267.59
# 29  [{'id': 800, 'main': 'Clear', 'description': '...  269.09    268.15
# ..                                                ...     ...       ...
# 70  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 71  [{'id': 800, 'main': 'Clear', 'description': '...  269.04    267.59
# 72  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 73  [{'id': 800, 'main': 'Clear', 'description': '...  269.04    267.59
# 74  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 75  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 76  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 77  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 78  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 79  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 80  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 81  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 82  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 83  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 84  [{'id': 800, 'main': 'Clear', 'description': '...  269.03    267.59
# 85  [{'id': 800, 'main': 'Clear', 'description': '...  268.99    267.59
# 86  [{'id': 800, 'main': 'Clear', 'description': '...  269.02    267.59
# 87  [{'id': 800, 'main': 'Clear', 'description': '...  269.02    267.59
# 88  [{'id': 800, 'main': 'Clear', 'description': '...  268.01    266.48
# 89  [{'id': 800, 'main': 'Clear', 'description': '...  268.01    266.48
# 90  [{'id': 800, 'main': 'Clear', 'description': '...  268.01    266.48
# 91  [{'id': 800, 'main': 'Clear', 'description': '...  268.01    266.48
# 92  [{'id': 800, 'main': 'Clear', 'description': '...  273.27    271.15
# 93  [{'id': 800, 'main': 'Clear', 'description': '...  273.28    271.48
# 94  [{'id': 800, 'main': 'Clear', 'description': '...  273.27    271.15
# 95  [{'id': 802, 'main': 'Clouds', 'description': ...  273.42    272.04
# 96  [{'id': 800, 'main': 'Clear', 'description': '...  273.53    271.48
# 97  [{'id': 800, 'main': 'Clear', 'description': '...  273.19    271.48
# 98  [{'id': 800, 'main': 'Clear', 'description': '...  273.02    271.48
# 99  [{'id': 800, 'main': 'Clear', 'description': '...  273.55    272.04
#
#     temp_max  visibility  wind_speed  normalized_delay
# 0     273.15     16093.0        3.60          0.517103
# 1     273.15     16093.0        6.70          0.517103
# 2     273.15     16093.0        3.60          0.517103
# 3     273.15     16093.0        6.70          0.517103
# 4     273.15     16093.0        2.60          0.517103
# 5     273.15     16093.0        6.70          0.413683
# 6     273.15     16093.0        2.60          0.517103
# 7     273.15     16093.0        6.70          0.413683
# 8     273.15     16093.0        2.60          0.517103
# 9     273.15     16093.0        6.70          0.310262
# 10    273.15     16093.0        2.60          0.517103
# 11    273.15     16093.0        6.70          0.206841
# 12    273.15     16093.0        6.70          0.103421
# 13    273.15     16093.0        6.70          0.103421
# 14    273.15     16093.0        5.70          0.000000
# 15    273.15     16093.0        5.70          0.000000
# 16    273.15     16093.0        5.70          0.000000
# 17    273.15     16093.0        5.70          0.000000
# 18    273.15     16093.0        5.70          0.000000
# 19    273.15     16093.0        5.70          0.000000
# 20    273.15     16093.0        5.70          0.000000
# 21    273.15     16093.0        6.20          0.000000
# 22    273.15     16093.0        6.20          0.000000
# 23    273.15     16093.0        5.70          0.000000
# 24    273.15     16093.0        6.20          0.000000
# 25    273.15     16093.0        6.20          0.000000
# 26    270.37     16093.0        4.60          0.206841
# 27    270.37     16093.0        4.60          0.206841
# 28    270.37     16093.0        4.60          0.206841
# 29    270.37     16093.0        4.60          0.206841
# ..       ...         ...         ...               ...
# 70    270.37     16093.0        7.20          0.206841
# 71    270.37     16093.0        3.60          0.103421
# 72    270.37     16093.0        7.20          0.103421
# 73    270.37     16093.0        3.60          0.000000
# 74    270.37     16093.0        7.20          0.103421
# 75    270.37     16093.0        7.20          0.000000
# 76    270.37     16093.0        7.20          0.000000
# 77    270.37     16093.0        7.20          0.000000
# 78    270.37     16093.0        7.20          0.103421
# 79    270.37     16093.0        7.20          0.000000
# 80    270.37     16093.0        7.20          0.000000
# 81    270.37     16093.0        7.20          0.000000
# 82    270.37     16093.0        7.20          0.000000
# 83    270.37     16093.0        7.20          0.000000
# 84    270.37     16093.0        7.20          0.000000
# 85    270.37     16093.0        7.20          0.000000
# 86    270.37     16093.0        7.20          0.000000
# 87    270.37     16093.0        7.20          0.000000
# 88    269.26     16093.0        2.10          0.000000
# 89    269.26     16093.0        2.10          0.000000
# 90    269.26     16093.0        2.10          0.000000
# 91    269.26     16093.0        2.10          0.000000
# 92    275.37     16093.0        3.22          0.206841
# 93    275.15     16093.0        1.67          0.000000
# 94    275.37     16093.0        3.22          0.103421
# 95    274.82     16093.0        2.60          0.206841
# 96    275.37     16093.0        1.50          0.000000
# 97    274.82     16093.0        1.62          0.103421
# 98    274.82     16093.0        1.32          0.000000
# 99    275.15     16093.0        3.17          0.103421
#
# [100 rows x 16 columns]

# %%
train_data['color'] = train_data.apply(colorRange, axis=1)

# %%
train_data['time_since_midnight'] = train_data.apply(timeSinceMidnight, axis=1)

# %%
train_data['time_group_since_midnight'] = train_data.apply(groupTime, axis=1)

# %%
train_data['lat_round'] = train_data.apply(lambda row: round(row['lat'],3), axis=1)
train_data['lon_round'] = train_data.apply(lambda row: round(row['lon'],3), axis=1)

# %%
train_data.head(100)

# %%
delay_group = train_data.groupby(['lat_round', 'lon_round', 'time_group_since_midnight'])['normalized_delay'].mean()
delay_group
# Out:
# lat_round  lon_round  time_group_since_midnight
# 41.414     -87.991    2700                          0.000000
#                       25200                         0.000000
#                       26100                         0.000000
#                       42300                         0.000000
# 41.415     -87.991    2700                          0.000000
#                       25200                         0.000000
#                       26100                         0.000000
#                       57600                         0.000000
#            -87.990    25200                         0.000000
# 41.416     -87.990    2700                          0.000000
#                       25200                         0.000000
#                       26100                         0.000000
#                       27900                         0.000000
#                       43200                         0.000000
#                       57600                         0.000000
# 41.417     -87.990    25200                         0.000000
#                       26100                         0.000000
#                       27900                         0.000000
#                       57600                         0.000000
#            -87.989    25200                         0.000000
#                       26100                         0.000000
#                       27900                         0.000000
# 41.418     -87.989    2700                          0.000000
#                       25200                         0.000000
#                       26100                         0.051710
#                       27900                         0.000000
#                       57600                         0.000000
#                       58500                         0.000000
# 41.419     -87.989    2700                          0.000000
#                       25200                         0.038783
#                                                      ...
# 42.585     -87.826    54900                         0.284407
#                       55800                         0.956641
#                       56700                         0.000000
#                       57600                         5.688138
#                       58500                         3.714527
#                       62100                         0.165473
#                       66600                         0.000000
#                       67500                         0.017237
#                       68400                         0.000000
#                       69300                         0.000000
#                       70200                         0.165473
#                       71100                         0.000000
#                       72000                         0.006084
#                       73800                         0.723945
#                       74700                         0.000000
#                       83700                         0.517103
# 42.586     -87.826    27900                         0.000000
#                       55800                         0.413683
#                       56700                         0.034474
#                       58500                         3.102621
#                       72900                         3.878276
#                       83700                         0.448156
# 42.587     -87.826    24300                         0.103421
#                       72900                         3.774855
#                       73800                         4.653931
#                       74700                        13.134428
#                       83700                         0.206841
# 42.588     -87.826    24300                         0.000000
#                       58500                         2.973345
#                       83700                         0.064638
# Name: normalized_delay, Length: 219249, dtype: float64

# %%
group_dict = {}
for group_id, group_delay in delay_group.iteritems():
    lat, lon, time = group_id
    try:
        current = group_dict[time]
    except KeyError:
        group_dict[time] = {0:{'lat': lat, 'lon': lon, 'delay': group_delay}}
    else:
        group_dict[time][len(current)] = {'lat': lat, 'lon': lon, 'delay': group_delay}

# %%
import json
with open('data/stops.json') as stops_file:  
    stops = json.load(stops_file)

# %%
time_groups = [time for time in range(0,86400,900)]
line_groups = {}
for time in time_groups:
    time_map = folium.Map(location=[41.8781,-87.6298], zoom_start=9)
    
    for stop in stops:
        marker = folium.CircleMarker([stop['stop_lat'],
                                      stop['stop_lon']], 
                                     radius=1, 
                                     popup=stop['stop_name'])
        marker.add_to(time_map)
        #time_map.keep_in_front(marker)
    
    try:
        time_group = group_dict[time]
    except KeyError:
        continue
    for index, delay_data in time_group.items():
        color = colorRangeNum(delay_data['delay'])
        marker = folium.CircleMarker([delay_data['lat'], delay_data['lon']],
                                     opacity=0.5,
                                     radius=0.5, color='#'+str(color)[2:], 
                                     fill_color='#'+str(color)[2:], 
                                     popup=str(int(delay_data['delay'] * (train_data['delay'].std() * 1))))
        marker.add_to(time_map)
    time_map.save('Maps/Time_Maps/Map_'+format_time(time)+'.html')

# %%
time_delay = train_data.groupby(['time_since_midnight', 'route_id'])['delay'].mean()

# %%
time_delay
# Out:
# time          route_id
# 1.554010e+09  BNSF        300.000000
#               UP-N        300.000000
#               BNSF        300.000000
#               UP-N        300.000000
#               BNSF        240.000000
#               UP-N        300.000000
#               BNSF        240.000000
#               UP-N        300.000000
#               BNSF        180.000000
#               UP-N        300.000000
#               BNSF        120.000000
#               UP-N        300.000000
#               BNSF         60.000000
#               BNSF         60.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
#               BNSF          0.000000
# 1.554026e+09  ME          120.000000
#               ME          120.000000
#               ME          120.000000
#               ME          120.000000
#                              ...
# 1.555328e+09  BNSF          0.000000
#               HC           30.000000
#               MD-N         72.000000
#               MD-W        192.000000
#               ME           30.000000
#               NCS           0.000000
#               RI           50.000000
#               SWS         180.000000
#               UP-N         60.000000
#               UP-NW        17.142857
#               UP-W         12.000000
#               BNSF          6.666667
#               HC           30.000000
#               MD-N         70.000000
#               MD-W        228.000000
#               ME           20.000000
#               NCS           0.000000
#               RI           60.000000
#               SWS         240.000000
#               UP-N         60.000000
#               UP-NW        17.142857
#               UP-W         12.000000
#               BNSF          0.000000
#               MD-N        180.000000
#               MD-W        120.000000
#               NCS           0.000000
#               RI          100.000000
#               UP-N         60.000000
#               UP-NW        15.000000
#               UP-W         30.000000
# Name: delay, Length: 176736, dtype: float64

# %%
time_delay_dict = {}
for info_id, delay in time_delay.iteritems():
    time, route = info_id
    time_delay_dict[len(time_delay_dict)] = {'time' : time, 'route_id': route, 'delay' : delay}

# %%
time_delay_df = pd.DataFrame.from_dict(time_delay_dict, orient='index')

# %%
time_delay_df
# Out:
#                 time route_id       delay
# 0       1.554010e+09     BNSF  300.000000
# 1       1.554010e+09     UP-N  300.000000
# 2       1.554010e+09     BNSF  300.000000
# 3       1.554010e+09     UP-N  300.000000
# 4       1.554010e+09     BNSF  240.000000
# 5       1.554010e+09     UP-N  300.000000
# 6       1.554010e+09     BNSF  240.000000
# 7       1.554010e+09     UP-N  300.000000
# 8       1.554010e+09     BNSF  180.000000
# 9       1.554010e+09     UP-N  300.000000
# 10      1.554010e+09     BNSF  120.000000
# 11      1.554010e+09     UP-N  300.000000
# 12      1.554010e+09     BNSF   60.000000
# 13      1.554010e+09     BNSF   60.000000
# 14      1.554010e+09     BNSF    0.000000
# 15      1.554010e+09     BNSF    0.000000
# 16      1.554010e+09     BNSF    0.000000
# 17      1.554010e+09     BNSF    0.000000
# 18      1.554010e+09     BNSF    0.000000
# 19      1.554010e+09     BNSF    0.000000
# 20      1.554010e+09     BNSF    0.000000
# 21      1.554010e+09     BNSF    0.000000
# 22      1.554010e+09     BNSF    0.000000
# 23      1.554010e+09     BNSF    0.000000
# 24      1.554010e+09     BNSF    0.000000
# 25      1.554010e+09     BNSF    0.000000
# 26      1.554026e+09       ME  120.000000
# 27      1.554026e+09       ME  120.000000
# 28      1.554026e+09       ME  120.000000
# 29      1.554026e+09       ME  120.000000
# ...              ...      ...         ...
# 176706  1.555328e+09     BNSF    0.000000
# 176707  1.555328e+09       HC   30.000000
# 176708  1.555328e+09     MD-N   72.000000
# 176709  1.555328e+09     MD-W  192.000000
# 176710  1.555328e+09       ME   30.000000
# 176711  1.555328e+09      NCS    0.000000
# 176712  1.555328e+09       RI   50.000000
# 176713  1.555328e+09      SWS  180.000000
# 176714  1.555328e+09     UP-N   60.000000
# 176715  1.555328e+09    UP-NW   17.142857
# 176716  1.555328e+09     UP-W   12.000000
# 176717  1.555328e+09     BNSF    6.666667
# 176718  1.555328e+09       HC   30.000000
# 176719  1.555328e+09     MD-N   70.000000
# 176720  1.555328e+09     MD-W  228.000000
# 176721  1.555328e+09       ME   20.000000
# 176722  1.555328e+09      NCS    0.000000
# 176723  1.555328e+09       RI   60.000000
# 176724  1.555328e+09      SWS  240.000000
# 176725  1.555328e+09     UP-N   60.000000
# 176726  1.555328e+09    UP-NW   17.142857
# 176727  1.555328e+09     UP-W   12.000000
# 176728  1.555328e+09     BNSF    0.000000
# 176729  1.555328e+09     MD-N  180.000000
# 176730  1.555328e+09     MD-W  120.000000
# 176731  1.555328e+09      NCS    0.000000
# 176732  1.555328e+09       RI  100.000000
# 176733  1.555328e+09     UP-N   60.000000
# 176734  1.555328e+09    UP-NW   15.000000
# 176735  1.555328e+09     UP-W   30.000000
#
# [176736 rows x 3 columns]

# %%
mod = smf.ols(formula='delay ~ time', data=time_delay_df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delay   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     205.4
# Date:                Tue, 23 Apr 2019   Prob (F-statistic):           1.46e-46
# Time:                        14:45:05   Log-Likelihood:            -1.3271e+06
# No. Observations:              176736   AIC:                         2.654e+06
# Df Residuals:                  176734   BIC:                         2.654e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.771e+04   4737.723    -14.292      0.000    -7.7e+04   -5.84e+04
# time        4.367e-05   3.05e-06     14.332      0.000    3.77e-05    4.96e-05
# ==============================================================================
# Omnibus:                   333437.323   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        814322233.852
# Skew:                          14.459   Prob(JB):                         0.00
# Kurtosis:                     334.278   Cond. No.                     7.02e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.02e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod = smf.ols(formula='delay ~ time + C(route_id)', data=train_data)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  delay   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     440.5
# Date:                Tue, 23 Apr 2019   Prob (F-statistic):               0.00
# Time:                        14:45:11   Log-Likelihood:            -3.8527e+06
# No. Observations:              495379   AIC:                         7.706e+06
# Df Residuals:                  495367   BIC:                         7.706e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -4.173e+04   3854.460    -10.827      0.000   -4.93e+04   -3.42e+04
# C(route_id)[T.HC]      202.2568     10.757     18.803      0.000     181.174     223.340
# C(route_id)[T.MD-N]    161.7475      3.353     48.246      0.000     155.177     168.318
# C(route_id)[T.MD-W]    105.0218      3.489     30.101      0.000      98.184     111.860
# C(route_id)[T.ME]        5.6196      3.102      1.811      0.070      -0.461      11.700
# C(route_id)[T.NCS]      34.1916      4.870      7.021      0.000      24.647      43.736
# C(route_id)[T.RI]      136.0499      3.673     37.036      0.000     128.850     143.250
# C(route_id)[T.SWS]      72.4447      4.967     14.586      0.000      62.710      82.179
# C(route_id)[T.UP-N]    115.6795      3.354     34.485      0.000     109.105     122.254
# C(route_id)[T.UP-NW]    94.4295      3.374     27.991      0.000      87.817     101.042
# C(route_id)[T.UP-W]    103.7598      3.470     29.899      0.000      96.958     110.562
# time                   2.69e-05   2.48e-06     10.851      0.000     2.2e-05    3.18e-05
# ==============================================================================
# Omnibus:                  1286887.421   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      49904869539.931
# Skew:                          29.991   Prob(JB):                         0.00
# Kurtosis:                    1556.763   Cond. No.                     7.31e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.31e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a308ad668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a30a102b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a211d2438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a211f8898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a21259cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2128a198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a212b15f8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a212d9a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a212d9ac8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dc18358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dc407b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dc69c18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dc9b0b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dcc3518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dcea978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dd14dd8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dd47278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2dd6c6d8>],
#       dtype=object)
